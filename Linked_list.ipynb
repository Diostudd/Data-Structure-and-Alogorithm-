# %% [markdown]
# # Single linked list

# %%
class Node:
    #A single node is a singke linked list
    def __init__(self,data):
        #Initializes the node with data and node pointer
        self.data = data
        self.next = None
    def __repr__(self):
        #Provides a helpful string representation for printing

        return str(self.data)
        
n1 = Node(55)
print(n1)
# Out:
# 55

# %%
class SingleLinkedlist:
    def __init__(self):
        self.head = None
        self.tail = None
        self.count = 0

    def is_empty(self):
        return self.head is None

    def __len__(self):
        return self.count

    def __repr__(self):
        nodes = []
        current = self.head
        while current:
            nodes.append(str(current.data))
            current = current.next
        return " -> ".join(nodes) + " -> None"

    def insert_at_beginning(self, data):
        new_node = Node(data)
        self.count += 1

        if self.is_empty():
            self.head = new_node
            self.tail = new_node
        else:
            new_node.next = self.head
            self.head = new_node


    def insertatend(self,data):
        #Inserts a new node at the end of the list.0(1) time with a tail pointer.
        new_node = Node(data)
        self.count += 1
        if self.is_empty():
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node

    def insertafternode(self,prev_node,data):
        #inserts a node after  given node.0(1) time if node reference is known
        if not prev_node:
            print("error:previous node is none")
            return
        
        #handles if previous node is the tail
        if prev_node == self.tail:
            self.insertatend(data)
            return
        
        new_node = Node(data)
        new_node.next = prev_node.next
        prev_node.next = new_node
        self.count += 1


    def deleteatbegginning(self):
        if self.is_empty():
            print("error list is empty")
            return None
        self.count -= 1
        nodetodelete = self.head
        #list has only one node
        if self.head == self.tail:
            self.head = None
            self.tail = None

        else:
            self.head = self.head.next
        return nodetodelete.data 
    
    
    
    
    
    
    def deleteatend(self):
        if self.is_empty():
            print("Error , the list is empty" )
            return None
        self.count -= 1

        #If only one node
        if self.head == self.tail:
            node_data = self.head.data
            self.head = None
            self.tail = None

            return node_data
        #Trnasverse to find the second to last node

        prev = self.head
        while prev.next != self.tail:
            prev = prev.next
        
        node_data = self.tail.data
        prev.next = None
        self.tail = prev #update the tail pointer
        return node_data
    


    
    
    def deletebykey(self,key):
        #Deletes the first node with the given key
        if self.is_empty():
            print("Error the list is empty")
        if self.head.data == key:
            self.deleteatbegginning()
            return
        prev = self.head
        current = self.head.next        
        while current:
            if current.data == key:
                prev.next = current.next
                if current == self.tail:
                    self.tail = prev
                self.count -= 1
                return
            prev = current
            current = current.next
        print(f"Error:key'{key}' not found in the list.")

    def transverse(self):

        print("SLL",end = " ")
        current = self.head
        while current:
            print(current.data, end = "->")
            current = current.next
        print("None")

    def search(self,key):
        current = self.head
        while current:
            if current.data == key:
                return current
            current = current.next
        return None

# %%
sll = SingleLinkedlist()
sll.insert_at_beginning(7)
print(sll)

sll.insert_at_beginning(20)
print(sll)
# Out:
# 7 -> None
# 20 -> 7 -> None

# %%
sll.insertatend(13)
print(sll)
# Out:
# 20 -> 7 -> 13 -> None

# %%
sll.deleteatbegginning()
print(sll)
# Out:
# 7 -> 13 -> None

# %%
sll.deleteatend()
print(sll)
# Out:
# 7 -> None

# %%
sll.search(7)
# Out:
# 7

# %% [markdown]
# # Doubly Linked list

# %%
class Node:
    def __init__(self,data):
        #Initializes the node with data and node pointer for next and prev
        self.data = data
        self.next = None
        self.prev = None
    def __repr__(self):
        #Provides a helpful string representation for printing

        return str(self.data)

# %%
class DoublyLinkedlist:
    def __init__(self):
        self.head = None
        self.tail = None
        self.count = 0

    def is_empty(self):
        return self.head is None

    def __len__(self):
        return self.count

    def __repr__(self):
        nodes = []
        current = self.head
        while current:
            nodes.append(str(current.data))
            current = current.next
        return "None <-> "+"<->".join(nodes) + " <-> None"
    
    def trans_forward(self):
        print("DLL forward:",end = " ")
        current = self.head
        while current:
            print(current.data,end = " <-> ")
            current = current.next
        print("None")
    
    
    def trans_backward(self):
        print("DLL Backward:",end=" ")
        current = self.tail
        while current:
            print(current.data,end= " <-> ")
            current = current.prev
        print("none")


    def insert_at_beginning(self, data):
        new_node = DNode(data)
        self.count += 1

        if self.is_empty():
            self.head = new_node
            self.tail = new_node
            return

        new_node.next = self.head
        self.head.prev = new_node
        self.head = new_node

    def insert_at_end(self, data):
        new_node = DNode(data)
        self.count += 1

        if self.is_empty():
            self.head = new_node
            self.tail = new_node
            return
        
        self.tail.next = new_node
        new_node.prev = self.tail
        self.tail = new_node

    def insert_after_node(self, prev_node, data):
        if prev_node is None:
            print("Error: previous node is None")
            return

        if prev_node == self.tail:
            self.insert_at_end(data)
            return

        new_node = DNode(data)
        new_node.next = prev_node.next
        new_node.prev = prev_node

        prev_node.next.prev = new_node
        prev_node.next = new_node

        self.count += 1

    # ---------------------------
    # DELETE OPERATIONS
    # ---------------------------

    def delete_at_beginning(self):
        if self.is_empty():
            print("Error: list is empty")
            return None
        
        node_data = self.head.data
        self.count -= 1

        if self.head == self.tail:
            self.head = None
            self.tail = None
            return node_data

        self.head = self.head.next
        self.head.prev = None

        return node_data

    def delete_at_end(self):
        if self.is_empty():
            print("Error: list is empty")
            return None
        
        node_data = self.tail.data
        self.count -= 1

        if self.head == self.tail:
            self.head = None
            self.tail = None
            return node_data

        self.tail = self.tail.prev
        self.tail.next = None

        return node_data

    def delete_by_key(self, key):
        if self.is_empty():
            print("Error: list is empty")
            return

        if self.head.data == key:
            self.delete_at_beginning()
            return

        current = self.head

        while current:
            if current.data == key:

                if current == self.tail:
                    self.delete_at_end()
                    return

                current.prev.next = current.next
                current.next.prev = current.prev
                self.count -= 1
                return

            current = current.next

        print(f"Error: key '{key}' not found in list")

# %%
class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        self.count = 0

    def is_empty(self):
        return self.head is None

    def __len__(self):
        return self.count

    def __repr__(self):
        nodes = []
        current = self.head
        while current:
            nodes.append(str(current.data))
            current = current.next
        return " <-> ".join(nodes) + " <-> None"

    # Insert at beginning
    def insert_at_beginning(self, data):
        new_node = DNode(data)
        self.count += 1

        if self.is_empty():
            self.head = new_node
            self.tail = new_node
            return
        
        new_node.next = self.head
        self.head.prev = new_node
        self.head = new_node

    # Insert at end
    def insert_at_end(self, data):
        new_node = DNode(data)
        self.count += 1

        if self.is_empty():
            self.head = new_node
            self.tail = new_node
            return
        
        self.tail.next = new_node
        new_node.prev = self.tail
        self.tail = new_node

    # Insert after a given node
    def insert_after_node(self, prev_node, data):
        if prev_node is None:
            print("Error: previous node is None")
            return
        
        # If previous node is the tail
        if prev_node == self.tail:
            self.insert_at_end(data)
            return
        
        new_node = DNode(data)
        new_node.next = prev_node.next
        new_node.prev = prev_node
        
        prev_node.next.prev = new_node
        prev_node.next = new_node
        
        self.count += 1

    # Delete at beginning
    def delete_at_beginning(self):
        if self.is_empty():
            print("Error: list is empty")
            return None
        
        self.count -= 1
        node_to_delete = self.head

        # If only one node
        if self.head == self.tail:
            self.head = None
            self.tail = None
            return node_to_delete.data
        
        self.head = self.head.next
        self.head.prev = None
        
        return node_to_delete.data

    # Delete at end
    def delete_at_end(self):
        if self.is_empty():
            print("Error: list is empty")
            return None
        
        self.count -= 1
        node_to_delete = self.tail

        # Only one node
        if self.head == self.tail:
            self.head = None
            self.tail = None
            return node_to_delete.data
        
        self.tail = self.tail.prev
        self.tail.next = None
        
        return node_to_delete.data

   
    def delete_by_key(self, key):
        if self.is_empty():
            print("Error: list is empty")
            return

        if self.head.data == key:
            self.delete_at_beginning()
            return

        current = self.head

        while current:
            if current.data == key:

                if current == self.tail:
                    self.delete_at_end()
                    return

                current.prev.next = current.next
                current.next.prev = current.prev
                self.count -= 1
                return

            current = current.next

        print(f"Error: key '{key}' not found in list")

# %%
class Node:
    def _init_(self,data):
        self.data=data
        self.next=None
class LL:
    def _init_(self):
        self.tail=self.head=None
        self.count=0
    def empty(self):
        return self.count==0
    def size(self):
        return self.count
    def append(self,data):
        node=Node(data)
        self.count+=1
        if self.empty():
            self.head=node
            self.tail=node
            return
        self.tail.next=node
        self.tail=node
    def prepend(self,data):
        node=Node(data)
        self.count+=1
        if self.empty():
            self.head=self.tail=node
            return
        node.next=self.head
        self.head=node
    def insert(self,prev,data):
        if self.empty():
            raise Exception
        if prev==self.tail:
            self.append(data)
            return
        current=Node(data)
        current.next=prev.next
        prev.next=current
        self.count+=1
    def remove_end(self):
        if self.empty():
            raise Exception
        if self.head is self.tail:
            self.head=self.tail=None
            self.count=0
        current=self.head
        while current.next!=self.tail:
            current=current.next
        current.next=None
        self.tail=current.head
        self.count-=1        
    def remove_front(self):
        if self.empty():
            raise Exception
        self.head.next=self.head
        if self.head is None:
            self.tail=None
    def remove(self, prev):
        if self.empty():
            raise Exception("List is empty")

        if prev.next is None:
            raise Exception("No node to remove after prev")

        node_to_remove = prev.next
        prev.next = node_to_remove.next

        if node_to_remove == self.tail:
            self.tail = prev

        self.count -= 1

# %%
class Node:
    def __init__(self,head):
        self.head = head
        self.next = None

# %%
class Stack:
    def __init__(self, capacity):
        self.capacity = capacity
        self.stack = [None] * capacity
        self.top = -1

    def isempty(self):
        return self.top == -1

    def isfull(self):
        return self.capacity == self.top + 1
